# %% [markdown]
# # Assignment - 5

# %% [markdown]
# 1.What does an empty dictionary&#39;s code look like?

# %% [markdown]
# Ans -  An empty dictionary is often represented by two empty curly brackets
#  d = {} or d = dict()

# %% [markdown]
# 2.What is the value of a dictionary value with the key &#39;foo&#39; and the value 42?

# %% [markdown]
# Ans- {'foo':42}

# %% [markdown]
# 3.What is the most significant distinction between a dictionary and a list?

# %% [markdown]
# Ans-Dictionaries are represented by {} where as listed are represented by []
# The Items stored in a dictionary are Unordered , while the items in a list are ordered

# %% [markdown]
# 4.What happens if you try to access spam[&#39;foo&#39;] if spam is {&#39;bar&#39;: 100}?

# %% [markdown]
# Ans- we will get a keyError KeyError: 'foo'

# %% [markdown]
# 5.If a dictionary is stored in spam, what is the difference between the expressions &#39;cat&#39; in spam and
# &#39;cat&#39; in spam.keys()?

# %% [markdown]
# Ans- There is no difference . The operator checks whether a value exits as a key in the dictionary or not

# %% [markdown]
# 6.If a dictionary is stored in spam, what is the difference between the expressions &#39;cat&#39; in spam and
# &#39;cat&#39; in spam.values()?

# %% [markdown]
# Ans- 'cat' in spam checks whether there is a 'cat' key in the dictionary, while 'cat' in spam.values() checks whether there is a value 'cat' for one of the keys in spam.

# %% [markdown]
# 7.What is a shortcut for the following code?
# if &#39;color&#39; not in spam:
# spam[&#39;color&#39;] = &#39;black&#39;

# %% [markdown]
# Ans- spam.setdefault('color','black')

# %% [markdown]
# 8.How do you &quot;pretty print&quot; dictionary values using which module and function?

# %% [markdown]
# Ans- using three function....

# %% [markdown]
# by using pprint() function of pprint module
# by using dumps() method of json module
# by using dumps() method of yaml module

# %%
ndict = [
  {'Name': 'Sam', 'Age': '21', 'Residence': {'Country':'USA', 'City': 'New York'}},
  {'Name': 'Mack', 'Age': '23', 'Residence': {'Country':'Spain', 'City': 'Madrid'}},
  {'Name': 'Dstar', 'Age': '32', 'Residence': {'Country':'UK', 'City': 'England'}},
  {'Name': 'Smr', 'Age': '19', 'Residence': {'Country':'Japan', 'City': 'Osaka'}}
]

print('Printing using print() function\n',ndict)
print('-'*70)
import pprint
print('Printing using pprint() funciton')
pprint.pprint(ndict)
print('-'*70)
import json
dump = json.dumps(ndict, indent=4)
print('Printing using dumps() method\n', dump)
print('-'*70)
import yaml
dump = yaml.dump(ndict)
print('Printing using dump() method\n', dump)
# Out:
# Printing using print() function
#  [{'Name': 'Sam', 'Age': '21', 'Residence': {'Country': 'USA', 'City': 'New York'}}, {'Name': 'Mack', 'Age': '23', 'Residence': {'Country': 'Spain', 'City': 'Madrid'}}, {'Name': 'Dstar', 'Age': '32', 'Residence': {'Country': 'UK', 'City': 'England'}}, {'Name': 'Smr', 'Age': '19', 'Residence': {'Country': 'Japan', 'City': 'Osaka'}}]
# ----------------------------------------------------------------------
# Printing using pprint() funciton
# [{'Age': '21',
#   'Name': 'Sam',
#   'Residence': {'City': 'New York', 'Country': 'USA'}},
#  {'Age': '23',
#   'Name': 'Mack',
#   'Residence': {'City': 'Madrid', 'Country': 'Spain'}},
#  {'Age': '32',
#   'Name': 'Dstar',
#   'Residence': {'City': 'England', 'Country': 'UK'}},
#  {'Age': '19',
#   'Name': 'Smr',
#   'Residence': {'City': 'Osaka', 'Country': 'Japan'}}]
# ----------------------------------------------------------------------
# Printing using dumps() method
#  [
#     {
#         "Name": "Sam",
# ...
